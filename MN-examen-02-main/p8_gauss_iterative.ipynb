# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2
from src import gauss_jacobi, gauss_seidel

# %% [markdown]
# # Ejercicio 1

# %%
A = [[2,1],[3,2]]
b = [5,8]

gauss_jacobi(A = A, b = b, x=[0,0])
# Out:
# [01-29 12:59:34][INFO][P3E009-E] i= 0 x: [[0. 0.]]
# [01-29 12:59:34][INFO][P3E009-E] i= 5 x: [[2.28125 2.6875 ]]
# array([[2.28125],
#        [2.6875 ]])

# %%
gauss_seidel(A = A, b = b, x=[0,0])
# Out:
# [01-29 12:59:34][INFO][P3E009-E] i= 0 x: [[0. 0.]]
# [01-29 12:59:34][INFO][P3E009-E] i= 1 x: [[2.5  0.25]]
# [01-29 12:59:34][INFO][P3E009-E] i= 2 x: [[2.375  0.4375]]
# [01-29 12:59:34][INFO][P3E009-E] i= 3 x: [[2.28125  0.578125]]
# [01-29 12:59:34][INFO][P3E009-E] i= 4 x: [[2.2109375  0.68359375]]
# [01-29 12:59:34][INFO][P3E009-E] i= 5 x: [[2.15820312 0.76269531]]
# array([[2.15820312],
#        [0.76269531]])

# %%
# Extraer valores de la trayectoria
# -- Datos de ejemplo --
x_values = [0.        ,2.5       ,2.375     ,2.28125   ,2.2109375 ,2.15820312,]
y_values = [0         ,0.25      ,0.4375    ,0.578125  ,0.68359375,0.76269531,]

import matplotlib.pyplot as plt

iterations = range(len(x_values))

# Dibujar trajectoria en el espacio 2D
plt.plot(x_values, y_values, "o:", markersize=4)
plt.plot(x_values[0], y_values[0], "gd", markersize=8, label="$X_0$", alpha=0.8)
plt.plot(x_values[-1], y_values[-1], "ro", markersize=8, label="$X_{sol}$", alpha=0.8)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Trajectoria")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Ejercicio 2

# %%
# %autoreload 2
from src import gauss_jacobi, gauss_seidel
A = [[1,1],[-2,1]]
b = [6,0]

# %%
gauss_jacobi(A = A, b = b, x=[0,0])
# Out:
# [01-29 12:59:34][INFO][P3E009-E] i= 0 x: [[0. 0.]]
# [01-29 12:59:34][INFO][P3E009-E] i= 5 x: [[ 18. -12.]]
# array([[ 18.],
#        [-12.]])

# %%
gauss_seidel(A = A, b = b, x=[1,3], max_iter=5)
# Out:
# [01-29 13:05:41][INFO][P3E009-E] i= 0 x: [[1. 3.]]
# [01-29 13:05:41][INFO][P3E009-E] i= 1 x: [[3. 6.]]
# [01-29 13:05:41][INFO][P3E009-E] i= 2 x: [[0. 0.]]
# [01-29 13:05:41][INFO][P3E009-E] i= 3 x: [[ 6. 12.]]
# [01-29 13:05:41][INFO][P3E009-E] i= 4 x: [[ -6. -12.]]
# [01-29 13:05:41][INFO][P3E009-E] i= 5 x: [[18. 36.]]
# array([[18.],
#        [36.]])

# %% [markdown]
# # Código para dibujar

# %%
# Extraer valores de la trayectoria
# -- Datos de ejemplo --
x_values = [0, 1, 0.5, 2, 2.5, 2.75, 2.9, 3.0]
y_values = [4.5, 5, 5.5, 4, 3.5, 3.25, 3.1, 3.0]

import matplotlib.pyplot as plt

iterations = range(len(x_values))

# Dibujar trajectoria en el espacio 2D
plt.plot(x_values, y_values, "o:", markersize=4)
plt.plot(x_values[0], y_values[0], "gd", markersize=8, label="$X_0$", alpha=0.8)
plt.plot(x_values[-1], y_values[-1], "ro", markersize=8, label="$X_{sol}$", alpha=0.8)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Trajectoria")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

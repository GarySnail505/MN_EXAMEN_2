# %%
import numpy as np
import matplotlib.pyplot as plt
#import scipy.optimize as opt

# %%
def f(x):
    return x**5 + 5.25*x**4 + 4.125*x**3 - 9.125*x**2 - 14.625*x - 5.625

# %%
x = np.linspace(-20,20,100)
y = f(x)

plt.plot(x,y)
plt.grid()
plt.show()

# %%
from numpy import round, sqrt

# %%
x1_real = -0.016107237
x2_real = -62.083893

a=1
b=62.1
c=1

# %%
x1_est_A = round(round(-b + round(sqrt(round(b**2,2)) + 4,2) )/2)
print(x1_est_A)
# Out:
# 2.0
